# %% [markdown]
# ## **Procesar y cortar Audio**

# %%
import librosa
import IPython.display as ipd
import numpy as np
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
import scipy
from scipy.io.wavfile import write
import shutil

def delete_splited_folder():
    if os.path.exists("splited"):
        shutil.rmtree("splited")

delete_splited_folder()

#@markdown - Sample Rate:
sr = 22050 #@param {type:"integer"}
#@markdown - Ruta de archivo + nombre:
ruta_de_archivo_de_audio = "/content/drive/MyDrive/Killjoy.wav" #@param {type:"string"}
#@markdown - prefijo, se puede dejar en blanco:
prefijo = "" #@param {type:"string"}
#@markdown ----
#@markdown - Descartar audios cortados de menos de X segundos:
descartar_menos_de = 1 #@param {type:"integer"}
#@markdown - Aplicar preenfasis al audio:
preemph = False #@param {type:"boolean"}
#@markdown - Coeficiente de preenfasis:
preemphasis = 0.8 #@param {type:"number"}

#@markdown - Tiempo mínimo entre segmentos (milisegundos):
min_diff = 400 #@param {type:"integer"}

#@markdown - Tamaño mínimo de segmentos (milisegundos):
min_size = 5000 #@param {type:"integer"}

#@markdown - Umbral de dB para detectar cortes:
db = 60 #@param {type:"number"}
def split_audio_to_list(source, preemph=True, preemphasis=0.8, min_diff=3000, min_size=3000, db=50):
    if preemph:
        source = np.append(source[0], source[1:] - preemphasis * source[:-1])
    split_list = librosa.effects.split(source, top_db=db).tolist()
    i = len(split_list) - 1
    while i > 0:
        if split_list[i][-1] - split_list[i][0] > min_size:
            now = split_list[i][0]
            prev = split_list[i - 1][1]
            diff = now - prev
            if diff < min_diff:
                split_list[i - 1] = [split_list[i - 1][0], split_list.pop(i)[1]]
        else:
            split_list.pop(i)
        i -= 1
    return [x for x in split_list if x[-1] - x[0] > min_size]

def trim_custom(audio, begin_db=25, end_db=30):
    begin = librosa.effects.trim(audio, top_db=begin_db)[1][0]
    end = librosa.effects.trim(audio, top_db=end_db)[1][1]
    return audio[begin:end]
# ...

def save_splits(audio, output_dir, i):
    output_path = os.path.join(output_dir, f"{prefijo}{i}.wav")
    scipy.io.wavfile.write(output_path, sr, audio)
    

y, _ = librosa.load(ruta_de_archivo_de_audio, sr=sr)
y_split = split_audio_to_list(y, preemph=preemph, preemphasis=preemphasis, min_diff=min_diff, min_size=min_size, db=db)
output_dir = "splited"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
for i, part in enumerate(y_split):
    audio = trim_custom(y[slice(*part)])
    
    # Descartar segmentos de audio de menos de un segundo
    if len(audio) < sr*descartar_menos_de:
        continue
    
    save_splits(audio, output_dir, i)
print("[1;32marchivos guardados correctamente")
# Out:
# archivos guardados correctamente

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@markdown #(Opcional)Mostrar audios
audio_dir = "splited"

# Obtener la lista de archivos de audio
audio_files = os.listdir(audio_dir)
audio_files = [x for x in audio_files if os.path.splitext(x)[1] == ".wav"]
# Ordenar la lista de archivos de audio por número
audio_files = sorted(audio_files, key=lambda x: int(os.path.splitext(x)[0]))

# Mostrar cada archivo de audio
for audio_file in audio_files:
    audio_path = os.path.join(audio_dir, audio_file)
    print(f"Reproduciendo {audio_file}:")
    ipd.display(ipd.Audio(audio_path))

# %%
from IPython.display import clear_output 
import os
#@markdown #(Opcional)Mostrar audios y elimina no deseados (de momento el boton con el nombre del audio lo elimina, esto es una opcion muy experimental, usala solo si entiendes de errores de programacion)
audio_dir = "splited"
def on_delete_clicked(b):
    # Obtener el nombre del archivo de audio a eliminar
    audio_file = b.original_description
    # Construir la ruta del archivo de audio
    audio_path = os.path.join(audio_dir, audio_file)
    # Eliminar el archivo
    os.remove(audio_path)
    # Refrescar el directorio de archivos de audio
    audio_files = os.listdir(audio_dir)
    audio_files = [x for x in audio_files if os.path.splitext(x)[1] == ".wav"]
    audio_files = sorted(audio_files, key=lambda x: int(os.path.splitext(x)[0]))
    # Refrescar el valor de start y end
    start = 0
    end = 10
    # Mostrar los archivos de audio
    clear_output()
    display(next_button, previous_button)
    show_audio_files(audio_files, start, end)

def show_audio_files(audio_files, start, end):
    print(f'mostrando audios del {start} al {end}')
    for audio_file in audio_files[start:end-1]:
        audio_path = os.path.join(audio_dir, audio_file)
        print(f"Reproduciendo {audio_file}:")
        ipd.display(ipd.Audio(audio_path))
        delete_button = widgets.Button(description=f"Eliminar {audio_file}")
        delete_button.original_description = audio_file
        delete_button.on_click(on_delete_clicked)
        display(delete_button)
        
def show_next_audio_files(b):
    global start, end
    start += 10
    end += 10
    audio_files = os.listdir(audio_dir)
    audio_files = [x for x in audio_files if os.path.splitext(x)[1] == ".wav"]
    audio_files = sorted(audio_files, key=lambda x: int(os.path.splitext(x)[0]))
    clear_output()
    display(next_button, previous_button)
    show_audio_files(audio_files, start, end)

def show_previous_audio_files(b):
    global start, end
    start -= 10
    end -= 10
    audio_files = os.listdir(audio_dir)
    audio_files = [x for x in audio_files if os.path.splitext(x)[1] == ".wav"]
    audio_files = sorted(audio_files, key=lambda x: int(os.path.splitext(x)[0]))
    clear_output()
    display(next_button, previous_button)
    show_audio_files(audio_files, start, end)

next_button = widgets.Button(description="Siguiente")
previous_button = widgets.Button(description="Anterior")

next_button.on_click(show_next_audio_files)
previous_button.on_click(show_previous_audio_files)

display(next_button, previous_button)
show_audio_files(audio_files, start, end)
# Out:
# Button(description='Siguiente', style=ButtonStyle())
# Button(description='Anterior', style=ButtonStyle())
# mostrando audios del 0 al 10
# Reproduciendo 2.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 2.wav', style=ButtonStyle())
# Reproduciendo 4.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 4.wav', style=ButtonStyle())
# Reproduciendo 5.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 5.wav', style=ButtonStyle())
# Reproduciendo 6.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 6.wav', style=ButtonStyle())
# Reproduciendo 8.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 8.wav', style=ButtonStyle())
# Reproduciendo 10.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 10.wav', style=ButtonStyle())
# Reproduciendo 11.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 11.wav', style=ButtonStyle())
# Reproduciendo 13.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 13.wav', style=ButtonStyle())
# Reproduciendo 15.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Button(description='Eliminar 15.wav', style=ButtonStyle())

# %%
#@markdown #(Opcional)Descarga todos los wavs separados en un zip
import shutil
from google.colab import files

def zip_and_download(folder_path, zip_file_name):
    shutil.make_archive(zip_file_name, "zip", folder_path)
    files.download(f"{zip_file_name}.zip")

# Crear ZIP y descargar archivo
zip_and_download("splited", "splited_files")

# %% [markdown]
# ## **Whisper**

# %%
#@markdown # Dependencias
# !pip install git+https://github.com/openai/whisper.git 
# !sudo apt update && sudo apt install ffmpeg
# !pip install librosa

import whisper
import time
import librosa
import soundfile as sf
import re
import os

# model = whisper.load_model("tiny.en")
# model = whisper.load_model("base.en")   
#model = whisper.load_model("small.en") # load the small model
#model = whisper.load_model("medium")
model = whisper.load_model("large")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-mqg5_khn
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-mqg5_khn
#   Resolved https://github.com/openai/whisper.git to commit 28769fcfe50755a817ab922a7bc83483159600a9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from whisper==1.0) (1.21.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from whisper==1.0) (1.13.0+cu116)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from whisper==1.0) (4.64.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.8/dist-packages (from whisper==1.0) (9.0.0)
# Collecting transformers>=4.19.0
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 86.8 MB/s eta 0:00:00
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from ffmpeg-python==0.2.0->whisper==1.0) (0.16.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->whisper==1.0) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 96.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->whisper==1.0) (3.8.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->whisper==1.0) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->whisper==1.0) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers>=4.19.0->whisper==1.0) (2.25.1)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->whisper==1.0) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers>=4.19.0->whisper==1.0) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=4.19.0->whisper==1.0) (2.10)
# Building wheels for collected packages: whisper
#   Building wheel for whisper (setup.py) ... done
#   Created wheel for whisper: filename=whisper-1.0-py3-none-any.whl size=1175340 sha256=36ce74309737422213bd0d5318ac567e9fc482972416fba97c9bacea6d9aeb40
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r3yozwrm/wheels/a7/70/18/b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# Successfully built whisper
# Installing collected packages: tokenizers, ffmpeg-python, huggingface-hub, transformers, whisper
# Successfully installed ffmpeg-python-0.2.0 huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1 whisper-1.0
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,127 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,549 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,573 kB]
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,349 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,348 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,389 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [30.9 kB]
# Get:21 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.2 kB]
# Fetched 13.7 MB in 2s (6,009 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 26 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 26 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: librosa in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.21.6)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.11.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.2.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.4.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.56.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (21.3)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.7.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa) (5.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.43.0->librosa) (3.11.0)
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:23<00:00, 133MiB/s]

# %%
#@markdown # Procesaremos todos los audios cortados anteriormente

# This will create the WhisperAudio files if they don't exist.

import shutil

eliminar_textos_anteriores = True #@param {type:"boolean"}

def delete_whisper_folder():
    if os.path.exists("/content/WhisperAudio/TextFiles"):
        print("borrando")
        shutil.rmtree("/content/WhisperAudio/TextFiles")

if eliminar_textos_anteriores:
  delete_whisper_folder()

folders =  ["WhisperAudio/", "WhisperAudio/TextFiles/"]
for folder in folders:
  path = folder
  if not os.path.exists(path): # Create the folder if it does not exist
    os.mkdir(path)

# Assuming the audio files are in a folder called "splited" in the root of the drive
audio_folder = "splited"  #@param {type:"string"}
select_language = 'es'#@param {type:"string"}
# Get a list of all the file paths and names in the folder
import os
audio_files = []
audio_names = []
for file in os.listdir(audio_folder):
  if file.endswith(".m4a") or file.endswith(".mp3") or file.endswith(".wav"):
    audio_files.append(audio_folder + "/" + file)
    audio_names.append(file)

for f in audio_files:    
  print(f)

if len(audio_files) == 0:
  print("You have no files.")

# Loop through the audio files, split each audio file based on pauses in speech then transcribe them with Whisper.
for i, file in enumerate(audio_files): # For each audio file
  print(f"Processing {audio_names[i]}...")
  # Load the audio file and convert it to 16 kHz mono
  audio, sr = librosa.load(file, sr=16000, mono=True)
  # Detect pauses and split the audio. We use a threshold of -30 dB and a minimum pause length of 0.5 seconds.
  pauses = librosa.effects.split(audio, top_db=30, frame_length=2048, hop_length=128)
  # Transcribe each segment and concatenate the results
  transcription = ""
  for start, end in pauses: # For each segment
    segment = audio[start:end]
    # Save the segment as a temporary wav file
    temp_file = "temp.wav"
    sf.write(temp_file, segment, sr, subtype='PCM_16')
    if os.path.getsize(temp_file) > 10000:
      #continue
      # Transcribe the segment with Whisper
      result = model.transcribe(temp_file, language= select_language)
      text = result["text"]
      # Append the text to the transcription
      print(len(transcription.split(" ")), "words processed")
      transcription += text.strip() + " "
      # Delete the temporary file
      os.remove(temp_file)
  # Print the transcription
  print(f"Transcription of {audio_names[i]}:\n")
  print(transcription)
  print("\n")
 
  # Convert the spaces between sections into paragraph breaks and save the transcription as a txt document in the same folder as MyAudio.
  transcription = re.sub(r"\s\s+", "\n\n", transcription) # Replace multiple spaces with newlines
  text_file = 'WhisperAudio' + "/TextFiles/" + audio_names[i][:-4] + ".txt" # Create the text file name
  with open(text_file, "w") as f: # Write the transcription to the text file
    f.write(transcription)
  print(f"Saved transcription as {text_file}")
# Out:
# splited/171.wav
# splited/94.wav
# splited/206.wav
# splited/161.wav
# splited/70.wav
# splited/6.wav
# splited/191.wav
# splited/95.wav
# splited/111.wav
# splited/255.wav
# splited/20.wav
# splited/174.wav
# splited/97.wav
# splited/226.wav
# splited/167.wav
# splited/179.wav
# splited/44.wav
# splited/139.wav
# splited/58.wav
# splited/149.wav
# splited/109.wav
# splited/5.wav
# splited/145.wav
# splited/219.wav
# splited/203.wav
# splited/117.wav
# splited/187.wav
# splited/243.wav
# splited/8.wav
# splited/47.wav
# splited/85.wav
# splited/1.wav
# splited/182.wav
# splited/35.wav
# splited/208.wav
# splited/185.wav
# splited/259.wav
# splited/150.wav
# splited/177.wav
# splited/66.wav
# splited/121.wav
# splited/36.wav
# splited/91.wav
# splited/69.wav
# splited/261.wav
# splited/137.wav
# splited/190.wav
# splited/143.wav
# splited/193.wav
# splited/250.wav
# splited/197.wav
# splited/267.wav
# splited/209.wav
# splited/119.wav
# splited/204.wav
# splited/134.wav
# splited/217.wav
# splited/146.wav
# splited/194.wav
# splited/78.wav
# splited/199.wav
# splited/225.wav
# splited/133.wav
# splited/258.wav
# splited/92.wav
# splited/148.wav
# splited/52.wav
# splited/39.wav
# splited/104.wav
# splited/17.wav
# splited/0.wav
# splited/108.wav
# splited/25.wav
# splited/122.wav
# splited/81.wav
# splited/2.wav
# splited/165.wav
# splited/229.wav
# splited/163.wav
# splited/84.wav
# splited/162.wav
# splited/113.wav
# splited/221.wav
# splited/79.wav
# splited/62.wav
# splited/30.wav
# splited/223.wav
# splited/118.wav
# splited/176.wav
# splited/110.wav
# splited/254.wav
# splited/228.wav
# splited/138.wav
# splited/101.wav
# splited/237.wav
# splited/87.wav
# splited/180.wav
# splited/127.wav
# splited/224.wav
# splited/54.wav
# splited/50.wav
# splited/131.wav
# splited/236.wav
# splited/192.wav
# splited/222.wav
# splited/164.wav
# splited/132.wav
# splited/207.wav
# splited/196.wav
# splited/96.wav
# splited/156.wav
# splited/11.wav
# splited/202.wav
# splited/22.wav
# splited/198.wav
# splited/188.wav
# splited/227.wav
# splited/181.wav
# splited/168.wav
# splited/253.wav
# splited/21.wav
# splited/106.wav
# splited/216.wav
# splited/105.wav
# splited/153.wav
# splited/93.wav
# splited/160.wav
# splited/53.wav
# splited/49.wav
# splited/60.wav
# splited/201.wav
# splited/63.wav
# splited/4.wav
# splited/74.wav
# splited/213.wav
# splited/263.wav
# splited/125.wav
# splited/175.wav
# splited/33.wav
# splited/155.wav
# splited/189.wav
# splited/200.wav
# splited/215.wav
# splited/65.wav
# splited/43.wav
# splited/240.wav
# splited/37.wav
# splited/234.wav
# splited/98.wav
# splited/90.wav
# splited/230.wav
# splited/152.wav
# splited/130.wav
# splited/13.wav
# splited/45.wav
# splited/46.wav
# splited/241.wav
# splited/114.wav
# splited/75.wav
# splited/166.wav
# splited/64.wav
# splited/18.wav
# splited/32.wav
# splited/178.wav
# splited/15.wav
# splited/220.wav
# splited/68.wav
# splited/16.wav
# splited/212.wav
# splited/3.wav
# splited/55.wav
# splited/249.wav
# splited/56.wav
# splited/27.wav
# splited/144.wav
# splited/77.wav
# splited/72.wav
# splited/140.wav
# splited/205.wav
# splited/238.wav
# splited/218.wav
# splited/88.wav
# splited/120.wav
# splited/83.wav
# splited/239.wav
# splited/10.wav
# splited/214.wav
# splited/173.wav
# Processing 171.wav...
# 1 words processed
# Transcription of 171.wav:
#
# Gracias, Matasita.
#
#
# Saved transcription as WhisperAudio/TextFiles/171.txt
# Processing 94.wav...
# 1 words processed
# Transcription of 94.wav:
#
# Yo los arreglo.
#
#
# Saved transcription as WhisperAudio/TextFiles/94.txt
# Processing 206.wav...
# 1 words processed
# Transcription of 206.wav:
#
# ¡Ah, el torre de tabaco!
#
#
# Saved transcription as WhisperAudio/TextFiles/206.txt
# Processing 161.wav...
# 1 words processed
# Transcription of 161.wav:
#
# Inicia la cuenta regresiva.
#
#
# Saved transcription as WhisperAudio/TextFiles/161.txt
# Processing 70.wav...
# 1 words processed
# Transcription of 70.wav:
#
# Me alegra mucho haberlos conocido.
#
#
# Saved transcription as WhisperAudio/TextFiles/70.txt
# Processing 6.wav...
# 1 words processed
# Transcription of 6.wav:
#
# Ustedes tampoco.
#
#
# Saved transcription as WhisperAudio/TextFiles/6.txt
# Processing 191.wav...
# 1 words processed
# Transcription of 191.wav:
#
# Busquemos los asesinatos.
#
#
# Saved transcription as WhisperAudio/TextFiles/191.txt
# Processing 95.wav...
# 1 words processed
# Transcription of 95.wav:
#
# Última ronda para usar sus créditos y habilidades.
#
#
# Saved transcription as WhisperAudio/TextFiles/95.txt
# Processing 111.wav...
# 1 words processed
# 8 words processed
# Transcription of 111.wav:
#
# Oh, quizás si dejan de jugar damas. Puedan ganar.
#
#
# Saved transcription as WhisperAudio/TextFiles/111.txt
# Processing 255.wav...
# 1 words processed
# Transcription of 255.wav:
#
# Torreta abajo.
#
#
# Saved transcription as WhisperAudio/TextFiles/255.txt
# Processing 20.wav...
# 1 words processed
# Transcription of 20.wav:
#
# Solo quiero ver todo lo que ha grabado.
#
#
# Saved transcription as WhisperAudio/TextFiles/20.txt
# Processing 174.wav...
# 1 words processed
# Transcription of 174.wav:
#
# ¡Hay que reevaluar la estrategia!
#
#
# Saved transcription as WhisperAudio/TextFiles/174.txt
# Processing 97.wav...
# 1 words processed
# Transcription of 97.wav:
#
# Última ronda para usar sus créditos y habilidades. No desperdicie ni una bala.
#
#
# Saved transcription as WhisperAudio/TextFiles/97.txt
# Processing 226.wav...
# 1 words processed
# Transcription of 226.wav:
#
# Bloquea ambición aquí.
#
#
# Saved transcription as WhisperAudio/TextFiles/226.txt
# Processing 167.wav...
# 1 words processed
# Transcription of 167.wav:
#
# Mi ulti casi está lista.
#
#
# Saved transcription as WhisperAudio/TextFiles/167.txt
# Processing 179.wav...
# 1 words processed
# Transcription of 179.wav:
#
# colocando granada de enjambre. Mi definitiva está lista.
#
#
# Saved transcription as WhisperAudio/TextFiles/179.txt
# Processing 44.wav...
# 1 words processed
# Transcription of 44.wav:
#
# Si esta ciudad me hubiera dejado instalar una matriz defensiva, no estaríamos aquí.
#
#
# Saved transcription as WhisperAudio/TextFiles/44.txt
# Processing 139.wav...
# 1 words processed
# Transcription of 139.wav:
#
# Le mostraré quién es la verdadera genio.
#
#
# Saved transcription as WhisperAudio/TextFiles/139.txt
# Processing 58.wav...
# 1 words processed
# Transcription of 58.wav:
#
# Quita mi tecnología.
#
#
# Saved transcription as WhisperAudio/TextFiles/58.txt
# Processing 149.wav...
# 1 words processed
# Transcription of 149.wav:
#
# ¿A quién llama soporte técnico, eh?
#
#
# Saved transcription as WhisperAudio/TextFiles/149.txt
# Processing 109.wav...
# 1 words processed
# Transcription of 109.wav:
#
# ¿A dónde iremos esta vez?
#
#
# Saved transcription as WhisperAudio/TextFiles/109.txt
# Processing 5.wav...
# 1 words processed
# 4 words processed
# Transcription of 5.wav:
#
# See you, Nomaestheres! Subtítulos por la comunidad de Amara.org
#
#
# Saved transcription as WhisperAudio/TextFiles/5.txt
# Processing 145.wav...
# 1 words processed
# Transcription of 145.wav:
#
# Deberían volver a evaluar su estrategia.
#
#
# Saved transcription as WhisperAudio/TextFiles/145.txt
# Processing 219.wav...
# 1 words processed
# Transcription of 219.wav:
#
# ¡Mi bot va a regresar!
#
#
# Saved transcription as WhisperAudio/TextFiles/219.txt
# Processing 203.wav...
# 1 words processed
# Transcription of 203.wav:
#
# Mi ultimo estalista.
#
#
# Saved transcription as WhisperAudio/TextFiles/203.txt
# Processing 117.wav...
# 1 words processed
# Transcription of 117.wav:
#
# análisis o estrategia.
#
#
# Saved transcription as WhisperAudio/TextFiles/117.txt
# Processing 187.wav...
# 1 words processed
# 7 words processed
# Transcription of 187.wav:
#
# Muerte por torreta. Varios enemigos detectados. Asesinato impecable.
#
#
# Saved transcription as WhisperAudio/TextFiles/187.txt
# Processing 243.wav...
# 1 words processed
# 2 words processed
# Transcription of 243.wav:
#
# ¡Ahhh! Bota el arma caído.
#
#
# Saved transcription as WhisperAudio/TextFiles/243.txt
# Processing 8.wav...
# 1 words processed
# Transcription of 8.wav:
#
# Fresca como una lechuga.
#
#
# Saved transcription as WhisperAudio/TextFiles/8.txt
# Processing 47.wav...
# 1 words processed
# Transcription of 47.wav:
#
# Tan lindo.
#
#
# Saved transcription as WhisperAudio/TextFiles/47.txt
# Processing 85.wav...
# 1 words processed
# Transcription of 85.wav:
#
# OK, ¿cada quien toma un tubo de ensayo?
#
#
# Saved transcription as WhisperAudio/TextFiles/85.txt
# Processing 1.wav...
# 1 words processed
# Transcription of 1.wav:
#
# Se lo leyeron, ¿verdad?
#
#
# Saved transcription as WhisperAudio/TextFiles/1.txt
# Processing 182.wav...
# 1 words processed
# Transcription of 182.wav:
#
# Atrapado y neutralizado.
#
#
# Saved transcription as WhisperAudio/TextFiles/182.txt
# Processing 35.wav...
# 1 words processed
# Transcription of 35.wav:
#
# Y sí, el internet está funcionando.
#
#
# Saved transcription as WhisperAudio/TextFiles/35.txt
# Processing 208.wav...
# 1 words processed
# Transcription of 208.wav:
#
# ¡Colocando botella de mar!
#
#
# Saved transcription as WhisperAudio/TextFiles/208.txt
# Processing 185.wav...
# 1 words processed
# Transcription of 185.wav:
#
# Lo siento, kleine Maus.
#
#
# Saved transcription as WhisperAudio/TextFiles/185.txt
# Processing 259.wav...
# 1 words processed
# Transcription of 259.wav:
#
# Ahora cuatro.
#
#
# Saved transcription as WhisperAudio/TextFiles/259.txt
# Processing 150.wav...
# 1 words processed
# Transcription of 150.wav:
#
# No pienses demasiado.
#
#
# Saved transcription as WhisperAudio/TextFiles/150.txt
# Processing 177.wav...
# 1 words processed
# 4 words processed
# Transcription of 177.wav:
#
# varios enemigos atractados. Tengo dinero. ¿Necesitas algo?
#
#
# Saved transcription as WhisperAudio/TextFiles/177.txt
# Processing 66.wav...
# 1 words processed
# Transcription of 66.wav:
#
# Solo fallaron esa vez.
#
#
# Saved transcription as WhisperAudio/TextFiles/66.txt
# Processing 121.wav...
# 1 words processed
# 6 words processed
# Transcription of 121.wav:
#
# Imagínense morir en este momento. Que gracioso.
#
#
# Saved transcription as WhisperAudio/TextFiles/121.txt
# Processing 36.wav...
# 1 words processed
# Transcription of 36.wav:
#
# Siempre está funcionando.
#
#
# Saved transcription as WhisperAudio/TextFiles/36.txt
# Processing 91.wav...
# 1 words processed
# Transcription of 91.wav:
#
# puedo cubrir muy bien una zona por mí misma.
#
#
# Saved transcription as WhisperAudio/TextFiles/91.txt
# Processing 69.wav...
# 1 words processed
# 4 words processed
# Transcription of 69.wav:
#
# NULLY N elephant Tal vez en si muero.
#
#
# Saved transcription as WhisperAudio/TextFiles/69.txt
# Processing 261.wav...
# 1 words processed
# Transcription of 261.wav:
#
# ¡Estoy ahorrando!
#
#
# Saved transcription as WhisperAudio/TextFiles/261.txt
# Processing 137.wav...
# 1 words processed
# 9 words processed
# Transcription of 137.wav:
#
# Ahora tengo que ponerle piernas a los ojos. ¡Pike!
#
#
# Saved transcription as WhisperAudio/TextFiles/137.txt
# Processing 190.wav...
# 1 words processed
# 25 words processed
# Transcription of 190.wav:
#
# colocando granadas enjambre. En desgracia a mi doctor ha visto que este hombre dejar algo horrible de Partida de Virginia," dijo la camarera. II. talento.
#
#
# Saved transcription as WhisperAudio/TextFiles/190.txt
# Processing 143.wav...
# 1 words processed
# 3 words processed
# Transcription of 143.wav:
#
# Podría mejorar. Con calma.
#
#
# Saved transcription as WhisperAudio/TextFiles/143.txt
# Processing 193.wav...
# 1 words processed
# 8 words processed
# Transcription of 193.wav:
#
# Gana el que le dé a más. ¡Ja! ¡Muerta por Toretta! ¡Despejemos esta zona!
#
#
# Saved transcription as WhisperAudio/TextFiles/193.txt
# Processing 250.wav...
# 1 words processed
# Transcription of 250.wav:
#
# Oh
#
#
# Saved transcription as WhisperAudio/TextFiles/250.txt
# Processing 197.wav...
# 1 words processed
# Transcription of 197.wav:
#
# Cuídate, Rey.
#
#
# Saved transcription as WhisperAudio/TextFiles/197.txt
# Processing 267.wav...
# 1 words processed
# Transcription of 267.wav:
#
# ¡A MAMI'S BOTS!
#
#
# Saved transcription as WhisperAudio/TextFiles/267.txt
# Processing 209.wav...
# 1 words processed
# Transcription of 209.wav:
#
# ¿Me ayudas con esto?
#
#
# Saved transcription as WhisperAudio/TextFiles/209.txt
# Processing 119.wav...
# 1 words processed
# Transcription of 119.wav:
#
# No te frustres.
#
#
# Saved transcription as WhisperAudio/TextFiles/119.txt
# Processing 204.wav...
# 1 words processed
# Transcription of 204.wav:
#
# ¡Destruyeron mi torreta!
#
#
# Saved transcription as WhisperAudio/TextFiles/204.txt
# Processing 134.wav...
# 1 words processed
# Transcription of 134.wav:
#
# Sabía que todo saldría bien.
#
#
# Saved transcription as WhisperAudio/TextFiles/134.txt
# Processing 217.wav...
# 1 words processed
# Transcription of 217.wav:
#
# eliminaron a mi voto
#
#
# Saved transcription as WhisperAudio/TextFiles/217.txt
# Processing 146.wav...
# 1 words processed
# Transcription of 146.wav:
#
# Al menos no intentas.
#
#
# Saved transcription as WhisperAudio/TextFiles/146.txt
# Processing 194.wav...
# 1 words processed
# Transcription of 194.wav:
#
# Precisión perfecta.
#
#
# Saved transcription as WhisperAudio/TextFiles/194.txt
# Processing 78.wav...
# 1 words processed
# Transcription of 78.wav:
#
# Y eres muy aterradora sin ella.
#
#
# Saved transcription as WhisperAudio/TextFiles/78.txt
# Processing 199.wav...
# 1 words processed
# Transcription of 199.wav:
#
# Spike destruida.
#
#
# Saved transcription as WhisperAudio/TextFiles/199.txt
# Processing 225.wav...
# 1 words processed
# Transcription of 225.wav:
#
# Cayó nuestra s-
#
#
# Saved transcription as WhisperAudio/TextFiles/225.txt
# Processing 133.wav...
# 1 words processed
# 2 words processed
# 5 words processed
# Transcription of 133.wav:
#
# ¡Talá! Sí, lo tengo. todo planeado.
#
#
# Saved transcription as WhisperAudio/TextFiles/133.txt
# Processing 258.wav...
# 1 words processed
# Transcription of 258.wav:
#
# Botalarma fuera.
#
#
# Saved transcription as WhisperAudio/TextFiles/258.txt
# Processing 92.wav...
# 1 words processed
# Transcription of 92.wav:
#
# Asegúrense de cubrir los ángulos que no puedo.
#
#
# Saved transcription as WhisperAudio/TextFiles/92.txt
# Processing 148.wav...
# 1 words processed
# Transcription of 148.wav:
#
# Parece que fui más lisa.
#
#
# Saved transcription as WhisperAudio/TextFiles/148.txt
# Processing 52.wav...
# 1 words processed
# Transcription of 52.wav:
#
# Ella conoce los míos.
#
#
# Saved transcription as WhisperAudio/TextFiles/52.txt
# Processing 39.wav...
# 1 words processed
# Transcription of 39.wav:
#
# ¿Robots asesinos?
#
#
# Saved transcription as WhisperAudio/TextFiles/39.txt
# Processing 104.wav...
# 1 words processed
# 6 words processed
# Transcription of 104.wav:
#
# ¡Gracias por ver el video! Sabía que sería fácil, pero.
#
#
# Saved transcription as WhisperAudio/TextFiles/104.txt
# Processing 17.wav...
# 1 words processed
# Transcription of 17.wav:
#
# ¿Alguien puede?
#
#
# Saved transcription as WhisperAudio/TextFiles/17.txt
# Processing 0.wav...
# 1 words processed
# Transcription of 0.wav:
#
# Bien, recopile algunos datos de nuestras últimas seis misiones.
#
#
# Saved transcription as WhisperAudio/TextFiles/0.txt
# Processing 108.wav...
# 1 words processed
# Transcription of 108.wav:
#
# Ay, mi ingenio no se queda en el laboratorio.
#
#
# Saved transcription as WhisperAudio/TextFiles/108.txt
# Processing 25.wav...
# 1 words processed
# Transcription of 25.wav:
#
# Es broma.
#
#
# Saved transcription as WhisperAudio/TextFiles/25.txt
# Processing 122.wav...
# 1 words processed
# Transcription of 122.wav:
#
# Ah, definitivamente no mereces mis inventos.
#
#
# Saved transcription as WhisperAudio/TextFiles/122.txt
# Processing 81.wav...
# 1 words processed
# Transcription of 81.wav:
#
# Nuestra tecnología es mejor.
#
#
# Saved transcription as WhisperAudio/TextFiles/81.txt
# Processing 2.wav...
# 1 words processed
# Transcription of 2.wav:
#
# ¿Aguien le llama?
#
#
# Saved transcription as WhisperAudio/TextFiles/2.txt
# Processing 165.wav...
# 1 words processed
# 2 words processed
# Transcription of 165.wav:
#
# Bye. Será mejor que corran.
#
#
# Saved transcription as WhisperAudio/TextFiles/165.txt
# Processing 229.wav...
# 1 words processed
# Transcription of 229.wav:
#
# Necesito curación.
#
#
# Saved transcription as WhisperAudio/TextFiles/229.txt
# Processing 163.wav...
# 1 words processed
# Transcription of 163.wav:
#
# Tuve que concentrarme más de lo normal.
#
#
# Saved transcription as WhisperAudio/TextFiles/163.txt
# Processing 84.wav...
# 1 words processed
# Transcription of 84.wav:
#
# Yo soy una jeoneo.
#
#
# Saved transcription as WhisperAudio/TextFiles/84.txt
# Processing 162.wav...
# 1 words processed
# Transcription of 162.wav:
#
# Ven cargo del Fantasmita.
#
#
# Saved transcription as WhisperAudio/TextFiles/162.txt
# Processing 113.wav...
# 1 words processed
# 2 words processed
# 3 words processed
# Transcription of 113.wav:
#
# tácticas. simples. Dejaré en deponcionar.
#
#
# Saved transcription as WhisperAudio/TextFiles/113.txt
# Processing 221.wav...
# 1 words processed
# Transcription of 221.wav:
#
# Asistencia de voz.
#
#
# Saved transcription as WhisperAudio/TextFiles/221.txt
# Processing 79.wav...
# 1 words processed
# Transcription of 79.wav:
#
# Su tecnología es solo tan buena como su habilidad.
#
#
# Saved transcription as WhisperAudio/TextFiles/79.txt
# Processing 62.wav...
# 1 words processed
# Transcription of 62.wav:
#
# de todas formas, Lore, pero...
#
#
# Saved transcription as WhisperAudio/TextFiles/62.txt
# Processing 30.wav...
# 1 words processed
# Transcription of 30.wav:
#
# Si veo solo un giroscopio desacomodado, no volverás a entrar a mi laboratorio.
#
#
# Saved transcription as WhisperAudio/TextFiles/30.txt
# Processing 223.wav...
# 1 words processed
# Transcription of 223.wav:
#
# ¡Cábalos, Reyna!
#
#
# Saved transcription as WhisperAudio/TextFiles/223.txt
# Processing 118.wav...
# 1 words processed
# Transcription of 118.wav:
#
# Es malísimo.
#
#
# Saved transcription as WhisperAudio/TextFiles/118.txt
# Processing 176.wav...
# 1 words processed
# Transcription of 176.wav:
#
# Mi definitiva estylista.
#
#
# Saved transcription as WhisperAudio/TextFiles/176.txt
# Processing 110.wav...
# 1 words processed
# Transcription of 110.wav:
#
# Recuerden lo que nos funcionó antes.
#
#
# Saved transcription as WhisperAudio/TextFiles/110.txt
# Processing 254.wav...
# 1 words processed
# Transcription of 254.wav:
#
# La Bíblia.
#
#
# Saved transcription as WhisperAudio/TextFiles/254.txt
# Processing 228.wav...
# 1 words processed
# Transcription of 228.wav:
#
# ¡Cayó nuestra Spike!
#
#
# Saved transcription as WhisperAudio/TextFiles/228.txt
# Processing 138.wav...
# 1 words processed
# Transcription of 138.wav:
#
# ¡Eso es lo mejor que pueden hacer!
#
#
# Saved transcription as WhisperAudio/TextFiles/138.txt
# Processing 101.wav...
# 1 words processed
# Transcription of 101.wav:
#
# Con tu permiso, me llevaré esos datos biométricos.
#
#
# Saved transcription as WhisperAudio/TextFiles/101.txt
# Processing 237.wav...
# 1 words processed
# Transcription of 237.wav:
#
# Bota el arma caído.
#
#
# Saved transcription as WhisperAudio/TextFiles/237.txt
# Processing 87.wav...
# 1 words processed
# Transcription of 87.wav:
#
# Recolectemos muestras y salgamos de aquí.
#
#
# Saved transcription as WhisperAudio/TextFiles/87.txt
# Processing 180.wav...
# 1 words processed
# Transcription of 180.wav:
#
# Se quedaron sin ojos.
#
#
# Saved transcription as WhisperAudio/TextFiles/180.txt
# Processing 127.wav...
# 1 words processed
# Transcription of 127.wav:
#
# Un paso más cerca de Rare es hará mi pijama.
#
#
# Saved transcription as WhisperAudio/TextFiles/127.txt
# Processing 224.wav...
# 1 words processed
# Transcription of 224.wav:
#
# colocando un sentinela.
#
#
# Saved transcription as WhisperAudio/TextFiles/224.txt
# Processing 54.wav...
# 1 words processed
# Transcription of 54.wav:
#
# Qué lástima prevar al mundo de una mente tan brillante.
#
#
# Saved transcription as WhisperAudio/TextFiles/54.txt
# Processing 50.wav...
# 1 words processed
# Transcription of 50.wav:
#
# Conozca todos los trucos de Soakiel Joy.
#
#
# Saved transcription as WhisperAudio/TextFiles/50.txt
# Processing 131.wav...
# 1 words processed
# Transcription of 131.wav:
#
# OK, ¿ya terminamos con eso? Ahora bajar este lugar.
#
#
# Saved transcription as WhisperAudio/TextFiles/131.txt
# Processing 236.wav...
# 1 words processed
# Transcription of 236.wav:
#
# ¡Enemigo derrivado!
#
#
# Saved transcription as WhisperAudio/TextFiles/236.txt
# Processing 192.wav...
# 1 words processed
# Transcription of 192.wav:
#
# Mi bot va de regreso.
#
#
# Saved transcription as WhisperAudio/TextFiles/192.txt
# Processing 222.wav...
# 1 words processed
# Transcription of 222.wav:
#
# ¡Enemigo detectado!
#
#
# Saved transcription as WhisperAudio/TextFiles/222.txt
# Processing 164.wav...
# 1 words processed
# Transcription of 164.wav:
#
# No interrumpan mi trabajo.
#
#
# Saved transcription as WhisperAudio/TextFiles/164.txt
# Processing 132.wav...
# 1 words processed
# Transcription of 132.wav:
#
# Genial. Ya estoy descifrando su código.
#
#
# Saved transcription as WhisperAudio/TextFiles/132.txt
# Processing 207.wav...
# 1 words processed
# Transcription of 207.wav:
#
# colocando botalarma.
#
#
# Saved transcription as WhisperAudio/TextFiles/207.txt
# Processing 196.wav...
# 1 words processed
# 3 words processed
# Transcription of 196.wav:
#
# Espera, ens... ¿En serio? No se expongan demasiado.
#
#
# Saved transcription as WhisperAudio/TextFiles/196.txt
# Processing 96.wav...
# 1 words processed
# Transcription of 96.wav:
#
# No desperdicie ni una bala.
#
#
# Saved transcription as WhisperAudio/TextFiles/96.txt
# Processing 156.wav...
# 1 words processed
# Transcription of 156.wav:
#
# Encontremos su debilidad y aprovechémosla.
#
#
# Saved transcription as WhisperAudio/TextFiles/156.txt
# Processing 11.wav...
# 1 words processed
# Transcription of 11.wav:
#
# Literalmente construí todo lo que hay en este campo de batalla.
#
#
# Saved transcription as WhisperAudio/TextFiles/11.txt
# Processing 202.wav...
# 1 words processed
# Transcription of 202.wav:
#
# Granada de enjambre afuera.
#
#
# Saved transcription as WhisperAudio/TextFiles/202.txt
# Processing 22.wav...
# 1 words processed
# 6 words processed
# Transcription of 22.wav:
#
# Sí, Samuel, tengo un rezo. de sus recuerdos de la base.
#
#
# Saved transcription as WhisperAudio/TextFiles/22.txt
# Processing 198.wav...
# 1 words processed
# Transcription of 198.wav:
#
# Oh, ok.
#
#
# Saved transcription as WhisperAudio/TextFiles/198.txt
# Processing 188.wav...
# 1 words processed
# 4 words processed
# Transcription of 188.wav:
#
# Mi ultimo es... Talis
#
#
# Saved transcription as WhisperAudio/TextFiles/188.txt
# Processing 227.wav...
# 1 words processed
# Transcription of 227.wav:
#
# Sé que puedes mejorar.
#
#
# Saved transcription as WhisperAudio/TextFiles/227.txt
# Processing 181.wav...
# 1 words processed
# Transcription of 181.wav:
#
# ¡Mi ulticasis está lista!
#
#
# Saved transcription as WhisperAudio/TextFiles/181.txt
# Processing 168.wav...
# 1 words processed
# Transcription of 168.wav:
#
# Enfócate en tu especialidad.
#
#
# Saved transcription as WhisperAudio/TextFiles/168.txt
# Processing 253.wav...
# 1 words processed
# Transcription of 253.wav:
#
# ¡A vivir sen!
#
#
# Saved transcription as WhisperAudio/TextFiles/253.txt
# Processing 21.wav...
# 1 words processed
# Transcription of 21.wav:
#
# No se preocupen equipo.
#
#
# Saved transcription as WhisperAudio/TextFiles/21.txt
# Processing 106.wav...
# 1 words processed
# Transcription of 106.wav:
#
# Si quieren la próxima vez, solo traeré una calculadora.
#
#
# Saved transcription as WhisperAudio/TextFiles/106.txt
# Processing 216.wav...
# 1 words processed
# Transcription of 216.wav:
#
# Eliminaron a mi bot.
#
#
# Saved transcription as WhisperAudio/TextFiles/216.txt
# Processing 105.wav...
# 1 words processed
# Transcription of 105.wav:
#
# ¡Maine coote!
#
#
# Saved transcription as WhisperAudio/TextFiles/105.txt
# Processing 153.wav...
# 1 words processed
# 2 words processed
# Transcription of 153.wav:
#
# Jerregito! ador.
#
#
# Saved transcription as WhisperAudio/TextFiles/153.txt
# Processing 93.wav...
# 1 words processed
# Transcription of 93.wav:
#
# Cuando ganemos, dejen todos sus aparatos en mi laboratorio.
#
#
# Saved transcription as WhisperAudio/TextFiles/93.txt
# Processing 160.wav...
# 1 words processed
# 3 words processed
# Transcription of 160.wav:
#
# Tengo dinero. ¿Necesitas algo?
#
#
# Saved transcription as WhisperAudio/TextFiles/160.txt
# Processing 53.wav...
# 1 words processed
# Transcription of 53.wav:
#
# ¡Ja! ¡Por fin un desafío para mí! Hay una Viper de su lado.
#
#
# Saved transcription as WhisperAudio/TextFiles/53.txt
# Processing 49.wav...
# 1 words processed
# Transcription of 49.wav:
#
# Me recuerdan algunos de mis proyectos en el kindergarten.
#
#
# Saved transcription as WhisperAudio/TextFiles/49.txt
# Processing 60.wav...
# 1 words processed
# Transcription of 60.wav:
#
# Me siento mal por matar a su Brimstone.
#
#
# Saved transcription as WhisperAudio/TextFiles/60.txt
# Processing 201.wav...
# 1 words processed
# Transcription of 201.wav:
#
# como relojito.
#
#
# Saved transcription as WhisperAudio/TextFiles/201.txt
# Processing 63.wav...
# 1 words processed
# Transcription of 63.wav:
#
# Me siento mal.
#
#
# Saved transcription as WhisperAudio/TextFiles/63.txt
# Processing 4.wav...
# 1 words processed
# Transcription of 4.wav:
#
# ¿Hay alguien aquí que se pude ir?
#
#
# Saved transcription as WhisperAudio/TextFiles/4.txt
# Processing 74.wav...
# 1 words processed
# Transcription of 74.wav:
#
# Llévate todo el refrigerante para reactores.
#
#
# Saved transcription as WhisperAudio/TextFiles/74.txt
# Processing 213.wav...
# 1 words processed
# Transcription of 213.wav:
#
# Enemigo detectado.
#
#
# Saved transcription as WhisperAudio/TextFiles/213.txt
# Processing 263.wav...
# 1 words processed
# Transcription of 263.wav:
#
# Ahora cuatro.
#
#
# Saved transcription as WhisperAudio/TextFiles/263.txt
# Processing 125.wav...
# 1 words processed
# 7 words processed
# Transcription of 125.wav:
#
# Esta shait se duele a vaso ¡Tante!
#
#
# Saved transcription as WhisperAudio/TextFiles/125.txt
# Processing 175.wav...
# 1 words processed
# Transcription of 175.wav:
#
# Podemos mantenerlos alejados.
#
#
# Saved transcription as WhisperAudio/TextFiles/175.txt
# Processing 33.wav...
# 1 words processed
# Transcription of 33.wav:
#
# Brimstone, recuerda, tu pantalla no está congelada.
#
#
# Saved transcription as WhisperAudio/TextFiles/33.txt
# Processing 155.wav...
# 1 words processed
# Transcription of 155.wav:
#
# No podemos seguir intentando lo mismo.
#
#
# Saved transcription as WhisperAudio/TextFiles/155.txt
# Processing 189.wav...
# 1 words processed
# Transcription of 189.wav:
#
# ¡Hora de una prueba de campo!
#
#
# Saved transcription as WhisperAudio/TextFiles/189.txt
# Processing 200.wav...
# 1 words processed
# Transcription of 200.wav:
#
# Variable eliminada.
#
#
# Saved transcription as WhisperAudio/TextFiles/200.txt
# Processing 215.wav...
# 1 words processed
# Transcription of 215.wav:
#
# Nada mal.
#
#
# Saved transcription as WhisperAudio/TextFiles/215.txt
# Processing 65.wav...
# 1 words processed
# Transcription of 65.wav:
#
# pueden confiar en mis bots.
#
#
# Saved transcription as WhisperAudio/TextFiles/65.txt
# Processing 43.wav...
# 1 words processed
# Transcription of 43.wav:
#
# Tranquilo, solo son asesinos cuando se los ordeno.
#
#
# Saved transcription as WhisperAudio/TextFiles/43.txt
# Processing 240.wav...
# 1 words processed
# Transcription of 240.wav:
#
# No pierdan la cabeza.
#
#
# Saved transcription as WhisperAudio/TextFiles/240.txt
# Processing 37.wav...
# 1 words processed
# Transcription of 37.wav:
#
# Granada, Zanjambre.
#
#
# Saved transcription as WhisperAudio/TextFiles/37.txt
# Processing 234.wav...
# 1 words processed
# Transcription of 234.wav:
#
# No me queden cargas.
#
#
# Saved transcription as WhisperAudio/TextFiles/234.txt
# Processing 98.wav...
# 1 words processed
# 5 words processed
# 8 words processed
# Transcription of 98.wav:
#
# Ah, ¿ya casi terminamos? ¡Ja, ja, ja! ¡JODER!
#
#
# Saved transcription as WhisperAudio/TextFiles/98.txt
# Processing 90.wav...
# 1 words processed
# Transcription of 90.wav:
#
# Piensan tanto que puedo oler cómo se queman sus circuitos.
#
#
# Saved transcription as WhisperAudio/TextFiles/90.txt
# Processing 230.wav...
# 1 words processed
# Transcription of 230.wav:
#
# ¡Les di a todos!
#
#
# Saved transcription as WhisperAudio/TextFiles/230.txt
# Processing 152.wav...
# 1 words processed
# Transcription of 152.wav:
#
# Calma, tenemos lo necesario para ganar.
#
#
# Saved transcription as WhisperAudio/TextFiles/152.txt
# Processing 130.wav...
# 1 words processed
# 2 words processed
# Transcription of 130.wav:
#
# ¡Kaiz! ¡Espera un minuto!
#
#
# Saved transcription as WhisperAudio/TextFiles/130.txt
# Processing 13.wav...
# 1 words processed
# Transcription of 13.wav:
#
# Incluso las cosas que podrían matarnos.
#
#
# Saved transcription as WhisperAudio/TextFiles/13.txt
# Processing 45.wav...
# 1 words processed
# 3 words processed
# 5 words processed
# Transcription of 45.wav:
#
# Optimus Prime En fin... Lo arreglaré por mi cuenta.
#
#
# Saved transcription as WhisperAudio/TextFiles/45.txt
# Processing 46.wav...
# 1 words processed
# Transcription of 46.wav:
#
# Cypher, tus dispositivos caseros son...
#
#
# Saved transcription as WhisperAudio/TextFiles/46.txt
# Processing 241.wav...
# 1 words processed
# Transcription of 241.wav:
#
# Necesito coración.
#
#
# Saved transcription as WhisperAudio/TextFiles/241.txt
# Processing 114.wav...
# 1 words processed
# Transcription of 114.wav:
#
# ¿Quién quiere hacer un informe?
#
#
# Saved transcription as WhisperAudio/TextFiles/114.txt
# Processing 75.wav...
# 1 words processed
# Transcription of 75.wav:
#
# ¿Si tus brazos se sobrecalientan?
#
#
# Saved transcription as WhisperAudio/TextFiles/75.txt
# Processing 166.wav...
# 1 words processed
# Transcription of 166.wav:
#
# Atrapado y neutralizado.
#
#
# Saved transcription as WhisperAudio/TextFiles/166.txt
# Processing 64.wav...
# 1 words processed
# 10 words processed
# 12 words processed
# Transcription of 64.wav:
#
# Todo el mundo se burla de la eficiencia alemana. Ja, ja. Sigan riéndose mientras usan todo mi equipamiento.
#
#
# Saved transcription as WhisperAudio/TextFiles/64.txt
# Processing 18.wav...
# 1 words processed
# Transcription of 18.wav:
#
# ¿Robar su hoja?
#
#
# Saved transcription as WhisperAudio/TextFiles/18.txt
# Processing 32.wav...
# 1 words processed
# Transcription of 32.wav:
#
# Pobre bote vigilancia.
#
#
# Saved transcription as WhisperAudio/TextFiles/32.txt
# Processing 178.wav...
# 1 words processed
# Transcription of 178.wav:
#
# ¡Somos mejores que ellos!
#
#
# Saved transcription as WhisperAudio/TextFiles/178.txt
# Processing 15.wav...
# 1 words processed
# Transcription of 15.wav:
#
# ¿Quieres que me disculpe?
#
#
# Saved transcription as WhisperAudio/TextFiles/15.txt
# Processing 220.wav...
# 1 words processed
# Transcription of 220.wav:
#
# Bloquea ambición aquí.
#
#
# Saved transcription as WhisperAudio/TextFiles/220.txt
# Processing 68.wav...
# 1 words processed
# Transcription of 68.wav:
#
# Nadie extrañará ese dedo.
#
#
# Saved transcription as WhisperAudio/TextFiles/68.txt
# Processing 16.wav...
# 1 words processed
# Transcription of 16.wav:
#
# ¿También hay un Sova en su equipo?
#
#
# Saved transcription as WhisperAudio/TextFiles/16.txt
# Processing 212.wav...
# 1 words processed
# Transcription of 212.wav:
#
# ¡Destruyeron mi torreta!
#
#
# Saved transcription as WhisperAudio/TextFiles/212.txt
# Processing 3.wav...
# 1 words processed
# Transcription of 3.wav:
#
# Maldita sea.
#
#
# Saved transcription as WhisperAudio/TextFiles/3.txt
# Processing 55.wav...
# 1 words processed
# Transcription of 55.wav:
#
# Pero ya es hora de que descanse.
#
#
# Saved transcription as WhisperAudio/TextFiles/55.txt
# Processing 249.wav...
# 1 words processed
# Transcription of 249.wav:
#
# Aún no puedo usarlo.
#
#
# Saved transcription as WhisperAudio/TextFiles/249.txt
# Processing 56.wav...
# 1 words processed
# 4 words processed
# Transcription of 56.wav:
#
# Está bien, Ares. Tal vez tus experimentos mejoraron un poco.
#
#
# Saved transcription as WhisperAudio/TextFiles/56.txt
# Processing 27.wav...
# 1 words processed
# Transcription of 27.wav:
#
# ¿Quisano?
#
#
# Saved transcription as WhisperAudio/TextFiles/27.txt
# Processing 144.wav...
# 1 words processed
# Transcription of 144.wav:
#
# Así sobrevivirás.
#
#
# Saved transcription as WhisperAudio/TextFiles/144.txt
# Processing 77.wav...
# 1 words processed
# 2 words processed
# Transcription of 77.wav:
#
# ¡Reina! Puedo ver por qué no quieres usar mi tecnología.
#
#
# Saved transcription as WhisperAudio/TextFiles/77.txt
# Processing 72.wav...
# 1 words processed
# Transcription of 72.wav:
#
# Y ahora en mi disco duro.
#
#
# Saved transcription as WhisperAudio/TextFiles/72.txt
# Processing 140.wav...
# 1 words processed
# Transcription of 140.wav:
#
# Una buena estrategia es mejor que cualquier arma.
#
#
# Saved transcription as WhisperAudio/TextFiles/140.txt
# Processing 205.wav...
# 1 words processed
# Transcription of 205.wav:
#
# ¡Despejemos esta zona!
#
#
# Saved transcription as WhisperAudio/TextFiles/205.txt
# Processing 238.wav...
# 1 words processed
# Transcription of 238.wav:
#
# ¿Me ayudas con esto?
#
#
# Saved transcription as WhisperAudio/TextFiles/238.txt
# Processing 218.wav...
# 1 words processed
# Transcription of 218.wav:
#
# Granada de Enjambre Fuera.
#
#
# Saved transcription as WhisperAudio/TextFiles/218.txt
# Processing 88.wav...
# 1 words processed
# 2 words processed
# Transcription of 88.wav:
#
# ¡SUSCRIBETE! Jejeje.
#
#
# Saved transcription as WhisperAudio/TextFiles/88.txt
# Processing 120.wav...
# 1 words processed
# Transcription of 120.wav:
#
# Si no sabes cómo, solo pregunta.
#
#
# Saved transcription as WhisperAudio/TextFiles/120.txt
# Processing 83.wav...
# 1 words processed
# Transcription of 83.wav:
#
# Los genios son los que ganan las batallas.
#
#
# Saved transcription as WhisperAudio/TextFiles/83.txt
# Processing 239.wav...
# 1 words processed
# Transcription of 239.wav:
#
# Nada mal.
#
#
# Saved transcription as WhisperAudio/TextFiles/239.txt
# Processing 10.wav...
# 1 words processed
# 6 words processed
# Transcription of 10.wav:
#
# Así se dice en español. español, ¿no?
#
#
# Saved transcription as WhisperAudio/TextFiles/10.txt
# Processing 214.wav...
# 1 words processed
# Transcription of 214.wav:
#
# colocando un sentinela.
#
#
# Saved transcription as WhisperAudio/TextFiles/214.txt
# Processing 173.wav...
# 1 words processed
# Transcription of 173.wav:
#
# Sé que puedes hacerlo mejor.
#
#
# Saved transcription as WhisperAudio/TextFiles/173.txt

# %%
#@markdown # Juntamos todos los textos generados en uno solo y agregamos el prefijo necesario para el dataset

import glob
import re

def reorder_text_file(text_dir, output_file, encoding="utf-8"):
    # Abrir el archivo de salida para escribir
    with open(output_file, "w", encoding=encoding) as out:
        # Obtener la lista de archivos de texto
        text_files = glob.glob(os.path.join(text_dir, "*.txt"))
        
        # Ordenar la lista de archivos de texto por número
        text_files = sorted(text_files, key=lambda x: int(os.path.splitext(os.path.basename(x))[0].split("_")[-1]))
        
        # Recorrer la lista de archivos de texto
        for text_file in text_files:
            # Abrir el archivo de texto para leer
            with open(text_file, encoding=encoding) as f:
                # Leer el contenido del archivo de texto
                text = f.read()
                
                # Extraer el nombre del archivo sin la extensión
                file_name = os.path.splitext(os.path.basename(text_file))[0]
                
                # Escribir el prefijo y el contenido del archivo de texto en el archivo de salida
                out.write(f"wavs/{file_name}.wav|{text}\n")

# Llamar a la función para mezclar los archivos de texto
reorder_text_file("WhisperAudio/TextFiles", "output.txt")

def clean_text(text):
    # Reemplazar tildes
    text = text.replace("á", "a").replace("é", "e").replace("í", "i").replace("ó", "o").replace("ú", "u")
    text = text.replace("Á", "A").replace("É", "E").replace("Í", "I").replace("Ó", "O").replace("Ú", "U")
    # Quitar signos de interrogación y admiración
    text = text.replace("?", "").replace("!", "").replace("¡", "").replace("¿", "").replace("...", "").replace(" .", ".")
    # Quitar ñ remplazando por ni
    text = text.replace("ñ", "ni")
    # Asegurar que hay un punto al final de cada línea
    text = [line.strip() + "." for line in text.split("\n")]
    return "\n".join(text)


def clean_output_file(input_file, output_file, encoding="utf-8"):
    # Abrir el archivo de entrada para leer
    with open(input_file, encoding=encoding) as f:
        # Leer el contenido del archivo de entrada
        text = f.read()
        
    # Limpiar el texto
    text = clean_text(text)
    
    # Abrir el archivo de salida para escribir
    with open(output_file, "w", encoding=encoding) as f:
        # Escribir el texto limpio en el archivo de salida
        f.write(text)

# Utilizar la función
input_file = "output.txt"
output_file = "output_clean.txt"
clean_output_file(input_file, output_file)
